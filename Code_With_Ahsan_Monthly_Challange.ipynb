# %% [markdown]
# <a href="https://colab.research.google.com/github/Jawwad-Ahmed-Khan/Monthly-Learning-Challenge/blob/main/Code_With_Ahsan_Monthly_Challange.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1 May

print("Provide User Name and Age:")
User_name = input("Enter Your User Name: ")
User_Age = int(input("Enter Your Age:"))

print(f"User Name: {User_name}\nAge:{User_Age}")
# Out:
# Provide User Name and Age:
# Enter Your User Name: Jawwad
# Enter Your Age:22
# User Name: Jawwad
# Age:22
